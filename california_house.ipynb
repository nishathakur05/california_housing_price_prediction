# %% [markdown]
# In \[489\]:
#
#     import pandas as pd
#
# In \[541\]:
#
#     df = pd.read_csv("./DATASET/housing.csv",low_memory=False)
#     df
#
# Out\[541\]:
#
# |       | longitude | latitude | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | median_house_value | ocean_proximity |
# |-------|-----------|----------|--------------------|-------------|----------------|------------|------------|---------------|--------------------|-----------------|
# | 0     | -122.23   | 37.88    | 41.0               | 880.0       | 129.0          | 322.0      | 126.0      | 8.3252        | 452600.0           | NEAR BAY        |
# | 1     | -122.22   | 37.86    | 21.0               | 7099.0      | 1106.0         | 2401.0     | 1138.0     | 8.3014        | 358500.0           | NEAR BAY        |
# | 2     | -122.24   | 37.85    | 52.0               | 1467.0      | 190.0          | 496.0      | 177.0      | 7.2574        | 352100.0           | NEAR BAY        |
# | 3     | -122.25   | 37.85    | 52.0               | 1274.0      | 235.0          | 558.0      | 219.0      | 5.6431        | 341300.0           | NEAR BAY        |
# | 4     | -122.25   | 37.85    | 52.0               | 1627.0      | 280.0          | 565.0      | 259.0      | 3.8462        | 342200.0           | NEAR BAY        |
# | ...   | ...       | ...      | ...                | ...         | ...            | ...        | ...        | ...           | ...                | ...             |
# | 20635 | -121.09   | 39.48    | 25.0               | 1665.0      | 374.0          | 845.0      | 330.0      | 1.5603        | 78100.0            | INLAND          |
# | 20636 | -121.21   | 39.49    | 18.0               | 697.0       | 150.0          | 356.0      | 114.0      | 2.5568        | 77100.0            | INLAND          |
# | 20637 | -121.22   | 39.43    | 17.0               | 2254.0      | 485.0          | 1007.0     | 433.0      | 1.7000        | 92300.0            | INLAND          |
# | 20638 | -121.32   | 39.43    | 18.0               | 1860.0      | 409.0          | 741.0      | 349.0      | 1.8672        | 84700.0            | INLAND          |
# | 20639 | -121.24   | 39.37    | 16.0               | 2785.0      | 616.0          | 1387.0     | 530.0      | 2.3886        | 89400.0            | INLAND          |
#
# 20640 rows × 10 columns
#
# In \[543\]:
#
#     df.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 20640 entries, 0 to 20639
#     Data columns (total 10 columns):
#      #   Column              Non-Null Count  Dtype
#     ---  ------              --------------  -----
#      0   longitude           20640 non-null  float64
#      1   latitude            20640 non-null  float64
#      2   housing_median_age  20640 non-null  float64
#      3   total_rooms         20640 non-null  float64
#      4   total_bedrooms      20433 non-null  float64
#      5   population          20640 non-null  float64
#      6   households          20640 non-null  float64
#      7   median_income       20640 non-null  float64
#      8   median_house_value  20640 non-null  float64
#      9   ocean_proximity     20640 non-null  object
#     dtypes: float64(9), object(1)
#     memory usage: 1.6+ MB
#
# In \[545\]:
#
#     df.isnull().sum()
#
# Out\[545\]:
#
#     longitude               0
#     latitude                0
#     housing_median_age      0
#     total_rooms             0
#     total_bedrooms        207
#     population              0
#     households              0
#     median_income           0
#     median_house_value      0
#     ocean_proximity         0
#     dtype: int64
#
# In \[547\]:
#
#     df.dropna(inplace=True)
#
# In \[549\]:
#
#     df.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     Index: 20433 entries, 0 to 20639
#     Data columns (total 10 columns):
#      #   Column              Non-Null Count  Dtype
#     ---  ------              --------------  -----
#      0   longitude           20433 non-null  float64
#      1   latitude            20433 non-null  float64
#      2   housing_median_age  20433 non-null  float64
#      3   total_rooms         20433 non-null  float64
#      4   total_bedrooms      20433 non-null  float64
#      5   population          20433 non-null  float64
#      6   households          20433 non-null  float64
#      7   median_income       20433 non-null  float64
#      8   median_house_value  20433 non-null  float64
#      9   ocean_proximity     20433 non-null  object
#     dtypes: float64(9), object(1)
#     memory usage: 1.7+ MB
#
# In \[551\]:
#
#     corr = df.corr(numeric_only=True)
#     corr
#
# Out\[551\]:
#
# |                    | longitude | latitude  | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | median_house_value |
# |--------------------|-----------|-----------|--------------------|-------------|----------------|------------|------------|---------------|--------------------|
# | longitude          | 1.000000  | -0.924616 | -0.109357          | 0.045480    | 0.069608       | 0.100270   | 0.056513   | -0.015550     | -0.045398          |
# | latitude           | -0.924616 | 1.000000  | 0.011899           | -0.036667   | -0.066983      | -0.108997  | -0.071774  | -0.079626     | -0.144638          |
# | housing_median_age | -0.109357 | 0.011899  | 1.000000           | -0.360628   | -0.320451      | -0.295787  | -0.302768  | -0.118278     | 0.106432           |
# | total_rooms        | 0.045480  | -0.036667 | -0.360628          | 1.000000    | 0.930380       | 0.857281   | 0.918992   | 0.197882      | 0.133294           |
# | total_bedrooms     | 0.069608  | -0.066983 | -0.320451          | 0.930380    | 1.000000       | 0.877747   | 0.979728   | -0.007723     | 0.049686           |
# | population         | 0.100270  | -0.108997 | -0.295787          | 0.857281    | 0.877747       | 1.000000   | 0.907186   | 0.005087      | -0.025300          |
# | households         | 0.056513  | -0.071774 | -0.302768          | 0.918992    | 0.979728       | 0.907186   | 1.000000   | 0.013434      | 0.064894           |
# | median_income      | -0.015550 | -0.079626 | -0.118278          | 0.197882    | -0.007723      | 0.005087   | 0.013434   | 1.000000      | 0.688355           |
# | median_house_value | -0.045398 | -0.144638 | 0.106432           | 0.133294    | 0.049686       | -0.025300  | 0.064894   | 0.688355      | 1.000000           |
#
# In \[553\]:
#
#     import seaborn as sns
#     import matplotlib.pyplot as plt
#
#     plt.figure(figsize=(8,6))
#     sns.heatmap(corr, annot=True, cmap="coolwarm")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[555\]:
#
#     from sklearn.model_selection import train_test_split
#     df['median_house_value'].dtype
#
#     y = df['median_house_value']
#     y
#     X = df.drop(['median_house_value'], axis= 1)
#
#     X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.2)
#
# In \[557\]:
#
#     train_data = X_train.join(y_train)
#
# In \[559\]:
#
#     train_data
#
# Out\[559\]:
#
# |       | longitude | latitude | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | ocean_proximity | median_house_value |
# |-------|-----------|----------|--------------------|-------------|----------------|------------|------------|---------------|-----------------|--------------------|
# | 17727 | -121.80   | 37.32    | 14.0               | 4412.0      | 924.0          | 2698.0     | 891.0      | 4.7027        | \<1H OCEAN      | 227600.0           |
# | 2057  | -119.63   | 36.64    | 33.0               | 1036.0      | 181.0          | 620.0      | 174.0      | 3.4107        | INLAND          | 110400.0           |
# | 6453  | -118.06   | 34.12    | 25.0               | 3891.0      | 848.0          | 1848.0     | 759.0      | 3.6639        | INLAND          | 248100.0           |
# | 4619  | -118.31   | 34.07    | 28.0               | 2362.0      | 949.0          | 2759.0     | 894.0      | 2.2364        | \<1H OCEAN      | 305600.0           |
# | 15266 | -117.27   | 33.04    | 27.0               | 1839.0      | 392.0          | 1302.0     | 404.0      | 3.5500        | NEAR OCEAN      | 214600.0           |
# | ...   | ...       | ...      | ...                | ...         | ...            | ...        | ...        | ...           | ...             | ...                |
# | 11397 | -117.97   | 33.72    | 24.0               | 2991.0      | 500.0          | 1437.0     | 453.0      | 5.4286        | \<1H OCEAN      | 273400.0           |
# | 12081 | -117.54   | 33.76    | 5.0                | 5846.0      | 1035.0         | 3258.0     | 1001.0     | 4.7965        | \<1H OCEAN      | 160800.0           |
# | 5447  | -118.42   | 34.01    | 42.0               | 1594.0      | 369.0          | 952.0      | 362.0      | 3.0990        | \<1H OCEAN      | 335400.0           |
# | 866   | -122.04   | 37.57    | 12.0               | 5719.0      | 1064.0         | 3436.0     | 1057.0     | 5.2879        | NEAR BAY        | 231200.0           |
# | 15948 | -122.43   | 37.73    | 52.0               | 3602.0      | 738.0          | 2270.0     | 647.0      | 3.8934        | NEAR BAY        | 251800.0           |
#
# 16346 rows × 10 columns
#
# In \[561\]:
#
#     train_data.hist(figsize=(10,12))
#
# Out\[561\]:
#
#     array([[<Axes: title={'center': 'longitude'}>,
#             <Axes: title={'center': 'latitude'}>,
#             <Axes: title={'center': 'housing_median_age'}>],
#            [<Axes: title={'center': 'total_rooms'}>,
#             <Axes: title={'center': 'total_bedrooms'}>,
#             <Axes: title={'center': 'population'}>],
#            [<Axes: title={'center': 'households'}>,
#             <Axes: title={'center': 'median_income'}>,
#             <Axes: title={'center': 'median_house_value'}>]], dtype=object)
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[487\]:
#
#     import numpy as np
#     train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
#     train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
#     train_data['population'] = np.log(train_data['population']+1)
#     train_data['households'] = np.log(train_data['households']+1)
#
# In \[563\]:
#
#     plt.figure(figsize=[10,6])
#     train_data.hist(figsize=[10,12])
#     plt.show()
#
#     <Figure size 1000x600 with 0 Axes>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[565\]:
#
#     import seaborn as sns
#
#     plt.figure(figsize=[10,12])
#     sns.scatterplot(x="latitude",y="longitude", hue="median_house_value", palette="coolwarm", data=train_data)
#
# Out\[565\]:
#
#     <Axes: xlabel='latitude', ylabel='longitude'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[516\]:
#
#     Q1= train_data["median_house_value"].quantile(0.25)
#     Q3= train_data["median_house_value"].quantile(0.75)
#
#     IQR = Q3 - Q1
#
#     low_fence = Q1 - (1.5 * IQR)
#     high_fence = Q3 + (1.5 * IQR)
#
#     print("Lower Fence: ",low_fence)
#     print("Higher Fence: ",high_fence)
#
#     print("Outliers above fence:", (train_data["median_house_value"] > high_fence).sum())
#
#     outliers = train_data[train_data["median_house_value"] >= high_fence].index
#     train_data.drop(outliers, axis=0, inplace=True)
#     train_data.count()
#
#     Lower Fence:  -97450.0
#     Higher Fence:  480550.0
#     Outliers above fence: 848
#
# Out\[516\]:
#
#     longitude             15498
#     latitude              15498
#     housing_median_age    15498
#     total_rooms           15498
#     total_bedrooms        15498
#     population            15498
#     households            15498
#     median_income         15498
#     ocean_proximity       15498
#     median_house_value    15498
#     dtype: int64
#
# In \[567\]:
#
#     sns.boxplot(x=train_data["median_house_value"])
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[569\]:
#
#     train_data.groupby("ocean_proximity")["median_house_value"].mean()
#
# Out\[569\]:
#
#     ocean_proximity
#     <1H OCEAN     239973.214908
#     INLAND        124873.471490
#     ISLAND        438233.333333
#     NEAR BAY      257941.456569
#     NEAR OCEAN    247054.193472
#     Name: median_house_value, dtype: float64
#
# In \[571\]:
#
#     train_data.groupby("ocean_proximity")["median_house_value"].agg(["mean", "max", "min"])
#
# Out\[571\]:
#
# |                 | mean          | max      | min      |
# |-----------------|---------------|----------|----------|
# | ocean_proximity |               |          |          |
# | \<1H OCEAN      | 239973.214908 | 500001.0 | 17500.0  |
# | INLAND          | 124873.471490 | 500001.0 | 14999.0  |
# | ISLAND          | 438233.333333 | 450000.0 | 414700.0 |
# | NEAR BAY        | 257941.456569 | 500001.0 | 22500.0  |
# | NEAR OCEAN      | 247054.193472 | 500001.0 | 28300.0  |
#
# In \[573\]:
#
#     train_data.groupby("ocean_proximity")["median_house_value"].count()
#
# Out\[573\]:
#
#     ocean_proximity
#     <1H OCEAN     7231
#     INLAND        5156
#     ISLAND           3
#     NEAR BAY      1842
#     NEAR OCEAN    2114
#     Name: median_house_value, dtype: int64
#
# In \[575\]:
#
#     train_data['bedroom_ratio']= train_data['total_bedrooms']/train_data['total_rooms']
#     train_data['bedroom_ratio']
#
# Out\[575\]:
#
#     17727    0.209429
#     2057     0.174710
#     6453     0.217939
#     4619     0.401778
#     15266    0.213159
#                ...
#     11397    0.167168
#     12081    0.177044
#     5447     0.231493
#     866      0.186047
#     15948    0.204886
#     Name: bedroom_ratio, Length: 16346, dtype: float64
#
# In \[577\]:
#
#     train_data.columns
#
# Out\[577\]:
#
#     Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#            'total_bedrooms', 'population', 'households', 'median_income',
#            'ocean_proximity', 'median_house_value', 'bedroom_ratio'],
#           dtype='object')
#
# In \[579\]:
#
#     test_data = X_test.join(y_test)
#     test_data['bedroom_ratio']= test_data['total_bedrooms']/test_data['total_rooms']
#
#     test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity'])).drop('ocean_proximity',axis=1)
#
#
#     X_test, y_test = test_data.drop('median_house_value',axis=1), test_data['median_house_value']
#
# In \[581\]:
#
#     train_data= train_data.join(pd.get_dummies(train_data['ocean_proximity'])).drop('ocean_proximity',axis=1)
#
# In \[583\]:
#
#     X_train, y_train = train_data.drop('median_house_value',axis=1), train_data['median_house_value']
#
# In \[585\]:
#
#     from sklearn.linear_model import LinearRegression
#     from sklearn.metrics import  r2_score
#
#
#     reg = LinearRegression()
#
#     reg.fit(X_train,y_train)
#
#     y_pred = reg.predict(X_test)
#
#     r2 = r2_score(y_test, y_pred)
#     print("R2 SQUARE RESULTS : " ,r2)
#
#     print("Accuracy : " ,reg.score(X_test,y_test))
#
#     R2 SQUARE RESULTS :  0.6530218415630722
#     Accuracy :  0.6530218415630722
#
# In \[539\]:
#
#     bool_cols = ['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']
#     X_train[bool_cols] = X_train[bool_cols].astype(int)
#     X_test[bool_cols] = X_test[bool_cols].astype(int)
#
#
#     from sklearn.linear_model import LinearRegression
#     from sklearn.metrics import  r2_score
#
#
#     reg = LinearRegression()
#
#     reg.fit(X_train,y_train)
#
#     y_pred = reg.predict(X_test)
#
#     r2 = r2_score(y_test, y_pred)
#     print("R2 SQUARE RESULTS : " ,r2)
#
#     print("Accuracy : " ,reg.score(X_test,y_test))
#
#     R2 SQUARE RESULTS :  0.642765217044725
#     Accuracy :  0.642765217044725
#
# In \[405\]:
#
#     print(X_test[:10])
#     print(X_train[:10])
#     print(y_train[:10])
#     print(y_pred[:10])   # see first few predictions
#     print(y_test[:10])   # see first few true values
#     print(X_train.columns)
#     print(X_test.columns)
#
#            longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#     14416    -117.24     32.79                20.0        961.0           278.0
#     16383    -121.29     38.01                 2.0       6403.0          1116.0
#     7731     -118.14     33.92                31.0       3731.0           853.0
#     1410     -122.07     37.94                30.0       1260.0           276.0
#     1335     -121.89     37.99                 4.0       2171.0           597.0
#     16260    -121.25     37.97                41.0        855.0           189.0
#     18011    -121.98     37.27                25.0       3075.0           564.0
#     10086    -117.96     33.94                34.0       2228.0           399.0
#     18294    -122.10     37.39                35.0       2471.0           349.0
#     18733    -122.39     40.53                28.0       1427.0           304.0
#
#            population  households  median_income  bedroom_ratio  <1H OCEAN  \
#     14416       525.0       254.0         3.1838       0.289282          0
#     16383      3327.0       957.0         4.4871       0.174293          0
#     7731       2313.0       801.0         3.2237       0.228625          1
#     1410        707.0       221.0         2.8920       0.219048          0
#     1335        928.0       461.0         4.1016       0.274988          0
#     16260       716.0       206.0         2.0375       0.221053          0
#     18011      1633.0       543.0         5.2528       0.183415          1
#     10086      1159.0       378.0         4.8906       0.179084          1
#     18294       881.0       342.0         7.6229       0.141238          0
#     18733       692.0       285.0         2.1250       0.213034          0
#
#            INLAND  ISLAND  NEAR BAY  NEAR OCEAN
#     14416       0       0         0           1
#     16383       1       0         0           0
#     7731        0       0         0           0
#     1410        0       0         1           0
#     1335        1       0         0           0
#     16260       1       0         0           0
#     18011       0       0         0           0
#     10086       0       0         0           0
#     18294       0       0         1           0
#     18733       1       0         0           0
#            longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#     17727    -121.80     37.32                14.0       4412.0           924.0
#     2057     -119.63     36.64                33.0       1036.0           181.0
#     6453     -118.06     34.12                25.0       3891.0           848.0
#     4619     -118.31     34.07                28.0       2362.0           949.0
#     15266    -117.27     33.04                27.0       1839.0           392.0
#     6823     -118.10     34.09                42.0       1460.0           289.0
#     8384     -118.36     33.95                26.0       3231.0          1089.0
#     2758     -115.49     32.67                29.0       1523.0           440.0
#     18143    -122.06     37.34                20.0       3435.0           593.0
#     1215     -120.46     38.09                16.0       3758.0           715.0
#
#            population  households  median_income  bedroom_ratio  <1H OCEAN  \
#     17727      2698.0       891.0         4.7027       0.209429          1
#     2057        620.0       174.0         3.4107       0.174710          0
#     6453       1848.0       759.0         3.6639       0.217939          0
#     4619       2759.0       894.0         2.2364       0.401778          1
#     15266      1302.0       404.0         3.5500       0.213159          0
#     6823        829.0       273.0         4.8750       0.197945          1
#     8384       3193.0      1020.0         2.6535       0.337047          1
#     2758       1302.0       393.0         1.1311       0.288903          0
#     18143      1293.0       553.0         6.7578       0.172635          1
#     1215       1777.0       615.0         3.0000       0.190261          0
#
#            INLAND  ISLAND  NEAR BAY  NEAR OCEAN
#     17727       0       0         0           0
#     2057        1       0         0           0
#     6453        1       0         0           0
#     4619        0       0         0           0
#     15266       0       0         0           1
#     6823        0       0         0           0
#     8384        0       0         0           0
#     2758        1       0         0           0
#     18143       0       0         0           0
#     1215        1       0         0           0
#     17727    227600.0
#     2057     110400.0
#     6453     248100.0
#     4619     305600.0
#     15266    214600.0
#     6823     227300.0
#     8384     177200.0
#     2758      84700.0
#     18143    451400.0
#     1215     122600.0
#     Name: median_house_value, dtype: float64
#     [203775.73139425 154552.40748187 196678.87352808 169746.06276694
#      198823.6123984   94664.79398626 278763.18114833 244557.11496877
#      368563.54817169  66600.67317216]
#     14416    245800.0
#     16383    137900.0
#     7731     218200.0
#     1410     220800.0
#     1335     170500.0
#     16260     75000.0
#     18011    269400.0
#     10086    228900.0
#     18294    500001.0
#     18733     80800.0
#     Name: median_house_value, dtype: float64
#     Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#            'total_bedrooms', 'population', 'households', 'median_income',
#            'bedroom_ratio', '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY',
#            'NEAR OCEAN'],
#           dtype='object')
#     Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#            'total_bedrooms', 'population', 'households', 'median_income',
#            'bedroom_ratio', '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY',
#            'NEAR OCEAN'],
#           dtype='object')
#
# In \[53\]:
#
#     print(train_data.duplicated().sum() )
#     print("\n")
#     train_data.describe()
#
#     0
#
# Out\[53\]:
#
# |       | longitude    | latitude     | housing_median_age | total_rooms  | total_bedrooms | population   | households   | median_income | median_house_value | bedroom_ratio |
# |-------|--------------|--------------|--------------------|--------------|----------------|--------------|--------------|---------------|--------------------|---------------|
# | count | 15498.000000 | 15498.000000 | 15498.000000       | 15498.000000 | 15498.000000   | 15498.000000 | 15498.000000 | 15498.000000  | 15498.000000       | 15498.000000  |
# | mean  | -119.573619  | 35.662587    | 28.329397          | 7.621051     | 6.058131       | 7.036778     | 5.987769     | 3.664343      | 190635.210801      | 0.793474      |
# | std   | 2.008191     | 2.151049     | 12.487762          | 0.746657     | 0.720337       | 0.731106     | 0.720869     | 1.551767      | 94978.379559       | 0.035372      |
# | min   | -124.350000  | 32.540000    | 1.000000           | 1.098612     | 1.098612       | 1.386294     | 1.098612     | 0.499900      | 14999.000000       | 0.403698      |
# | 25%   | -121.780000  | 33.930000    | 18.000000          | 7.272398     | 5.697093       | 6.680855     | 5.645447     | 2.523500      | 116100.000000      | 0.773169      |
# | 50%   | -118.520000  | 34.270000    | 28.000000          | 7.653969     | 6.079933       | 7.073270     | 6.018593     | 3.442650      | 173500.000000      | 0.793633      |
# | 75%   | -117.990000  | 37.730000    | 37.000000          | 8.042378     | 6.473891       | 7.463363     | 6.406880     | 4.575850      | 245800.000000      | 0.814464      |
# | max   | -114.470000  | 41.950000    | 52.000000          | 10.579514    | 8.771215       | 10.482430    | 8.713253     | 15.000100     | 479700.000000      | 1.000000      |
#
# In \[55\]:
#
#     import seaborn as sns
#
#     # Single column boxplot
#     sns.boxplot(y=train_data["median_house_value"])
#     train_data["median_house_value"].describe()
#     # plt.show()
#
# Out\[55\]:
#
#     count     15498.000000
#     mean     190635.210801
#     std       94978.379559
#     min       14999.000000
#     25%      116100.000000
#     50%      173500.000000
#     75%      245800.000000
#     max      479700.000000
#     Name: median_house_value, dtype: float64
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[57\]:
#
#     import seaborn as sns
#
#     # Single column boxplot
#     sns.boxplot(y=train_data["median_house_value"])
#     train_data["median_house_value"].describe()
#     # plt.show()
#
# Out\[57\]:
#
#     count     15498.000000
#     mean     190635.210801
#     std       94978.379559
#     min       14999.000000
#     25%      116100.000000
#     50%      173500.000000
#     75%      245800.000000
#     max      479700.000000
#     Name: median_house_value, dtype: float64
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[59\]:
#
#     sns.boxplot(data=train_data[["median_house_value", "median_income"]])
#     train_data["median_house_value"].describe()
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[ \]:
#
#
#
# In \[ \]:
